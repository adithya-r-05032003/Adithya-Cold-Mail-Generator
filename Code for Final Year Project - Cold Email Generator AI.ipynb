# %%
# !pip install langchain_groq
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    temperature=0, 
    groq_api_key='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', 
    model_name="llama-3.1-70b-versatile"
)
response = llm.invoke("The first person to land on moon was ...")
print(response.content)
# Out:
# The first person to land on the moon was Neil Armstrong. He stepped onto the lunar surface on July 20, 1969, as part of the Apollo 11 mission.

# %%
# !pip install langchain_community
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from langchain.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://jobs.nike.com/job/R-39013?from=job%20search%20funnel")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# Apply for Senior Software Engineer
#
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
type(res.content)
# Out:
# str

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# {'role': 'Senior Software Engineer',
#  'experience': 'Senior-level',
#  'skills': ['Python (preferred) or similar object-oriented programming languages',
#   'JavaScript front end-web frameworks (e.g. Angular, React)',
#   'Data structures and algorithms for efficiently and effectively managing large data sets',
#   'Serverless data warehouses (e.g. Athena) and NoSQL databases (e.g. DynamoDB)',
#   'GraphQL and RESTful APIs',
#   'Cloud infrastructure development using public cloud providers, e.g., AWS (our preferred choice), Azure, GCP',
#   'Infrastructure-as-code technologies (e.g., Terraform, CloudFormation, CircleCI), continuous integration & deployment (CI/CD), source control (e.g. GitHub), and build automation (e.g. Jenkins, GitHub Actions)',
#   'Agile principles and Sprint Planning, including planning/backlog tools (e.g., JIRA)'],
# ...

# %%
import pandas as pd

df = pd.read_csv("portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
# !pip install chromadb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached chromadb-0.5.15-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached chroma_hnswlib-0.7.6.tar.gz (32 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached fastapi-0.115.3-py3-none-any.whl.metadata (27 kB)
# ...
#   Using cached uvicorn-0.32.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached posthog-3.7.0-py2.py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached opentelemetry_api-1.27.0-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# ...

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 import uuid
# ----> 2 import chromadb
#       4 client = chromadb.PersistentClient('vectorstore')
#       5 collection = client.get_or_create_collection(name="portfolio")
#
# ModuleNotFoundError: No module named 'chromadb'

# %%
links = collection.query(query_texts=job['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/python-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/wordpress-portfolio'}]]

# %%
job
# Out:
# {'skills': ['Python', 'Machine Learning']}

# %%
job = json_res
job['skills']
# Out:
# ['Python (preferred) or similar object-oriented programming languages',
#  'JavaScript front end-web frameworks (e.g. Angular, React)',
#  'Data structures and algorithms for efficiently and effectively managing large data sets',
#  'Serverless data warehouses (e.g. Athena) and NoSQL databases (e.g. DynamoDB)',
#  'GraphQL and RESTful APIs',
#  'Cloud infrastructure development experience using public cloud providers, e.g., AWS (our preferred choice), Azure, GCP',
#  'Infrastructure-as-code technologies (e.g., Terraform, CloudFormation, CircleCI), continuous integration & deployment (CI/CD), source control (e.g. GitHub), and build automation (e.g. Jenkins, GitHub Actions)',
#  'Agile principles and Sprint Planning, including planning/backlog tools (e.g., JIRA)']

# %%
prompt_email = PromptTemplate.from_template(
    """
    ### JOB DESCRIPTION:
    {job_description}
    
    ### INSTRUCTION:
    You are Adithya R, a seasoned software consultant with extensive experience in AI, ML, and software development. Over the course of your career, you have successfully designed and implemented tailored solutions for various enterprises, enhancing scalability, optimizing processes, reducing costs, and driving overall efficiency. 
    Your job is to write a cold email to the client regarding the job mentioned above, describing your capability and expertise in fulfilling their needs.
    Also, add the most relevant ones from the following links to showcase your portfolio: {link_list}
    Remember you are Adithya R, a professional with significant work experience. 
    Do not provide a preamble.
    ### EMAIL (NO PREAMBLE):
    
    """
    )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Expert Software Engineer for Cloud Reporting Solution
#
# Dear Hiring Manager,
#
# I am writing to express my interest in the Senior Software Engineer position for your internal cloud reporting solution. With over a decade of experience in designing and implementing scalable software solutions, I am confident that my expertise aligns with your requirements.
#
# As a seasoned software consultant, I have a proven track record of delivering high-quality solutions that enhance scalability, optimize processes, reduce costs, and drive overall efficiency. My extensive experience in AI, ML, and software development has equipped me with the skills to tackle complex challenges and deliver tailored solutions that meet the unique needs of enterprises.
#
# In particular, I possess expertise in the following areas that are relevant to your job description:
#
# * Object-oriented programming languages, including Python
# * Front-end web frameworks such as Angular and React
# ...
